# %%
scan_mapping = {
  "ethereum": "0x1",
  "polygon-pos": "0x89",
  "binance-smart-chain": "0x38",
  # "optimistic-ethereum": "0xa",
  # "arbitrum-one": "0xa4b1",
  # "moonriver": "0x505",
  "fantom": "0xfa",
  # "moonbeam": "0x504",
}

# %%
from platform import platform
from crawler_service import TokenHolderStats
import pymongo
import pandas as pd

# %%
client = pymongo.MongoClient('mongodb+srv://admin:admin@db.5m3qg.mongodb.net/test?authSource=admin&replicaSet=atlas-dzj3vd-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true', 
                             username='admin', password='admin')

db = client["token"]
col = db["coincap5k"]

service = TokenHolderStats('0x1')

coincap5000 = pd.read_csv('data/coincap5000.csv')
coincap5000id = coincap5000['id'].to_list()

mapping = {}

for x in col.find():
  try:
    mapping[x['id']] = x['platforms']
  except:
    pass

# %%
coincap5000 = pd.read_csv('data/coincap5000.csv')
coin_id_list = coincap5000['id'].to_list()

# %%
total_holder_mapping = {}
error_list = []
for id in coin_id_list:  
  total_holder = 0
  
  try:
    for key, value in mapping[id].items():
      try:
        if (key in scan_mapping):
          service = TokenHolderStats(scan_mapping[key])
          holder = service.get_holder(value)
          total_holder += holder['total_holders'] 
          
      except:
        error_list.append(id)
    
    # Open a file with access mode 'a'
    file_object = open('data/coin_holder.txt', 'a')
    # Append 'hello' at the end of file
    s = id + ' ' + str(total_holder) + '\n' 
    file_object.write(s)
    # Close the file
    file_object.close()
      
  except:
    error_list.append(id)
            
  total_holder_mapping[id] = total_holder
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/trinhhung/d/tovchain/project-2/getData/test.ipynb Cell 5' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/trinhhung/d/tovchain/project-2/getData/test.ipynb#ch0000008?line=0'>1</a> total_holder_mapping = {}
#       <a href='vscode-notebook-cell:/home/trinhhung/d/tovchain/project-2/getData/test.ipynb#ch0000008?line=1'>2</a> error_list = []
# ----> <a href='vscode-notebook-cell:/home/trinhhung/d/tovchain/project-2/getData/test.ipynb#ch0000008?line=2'>3</a> for id in coin_id_list:
#       <a href='vscode-notebook-cell:/home/trinhhung/d/tovchain/project-2/getData/test.ipynb#ch0000008?line=3'>4</a>   total_holder = 0
#       <a href='vscode-notebook-cell:/home/trinhhung/d/tovchain/project-2/getData/test.ipynb#ch0000008?line=5'>6</a>   try:
#
# NameError: name 'coin_id_list' is not defined

# %%
for i in range (5):
  total_holder = 0
  # Open a file with access mode 'a'
  file_object = open('data/coin_holder.txt', 'a')
  # Append 'hello' at the end of file
  file_object.write(' hi \n')
  # Close the file
  file_object.close()

# %%
error_list
# Out:
# ['tether',
#  'tether',
#  'tether',
#  'tether',
#  'usd-coin',
#  'usd-coin',
#  'usd-coin',
#  'usd-coin',
#  'binance-usd',
#  'binance-usd',
#  'binance-usd',
#  'dogecoin',
#  'wrapped-bitcoin',
#  'wrapped-bitcoin',
#  'wrapped-bitcoin',
#  'avalanche-2',
#  'staked-ether',
#  'dai',
#  'dai',
#  'dai',
#  'dai',
#  'shiba-inu',
#  'leo-token',
#  'crypto-com-chain',
#  'matic-network',
#  'matic-network',
#  'matic-network',
#  'ftx-token',
#  'okb',
#  'chainlink',
#  'chainlink',
#  'chainlink',
#  'chainlink',
#  'cosmos',
#  'apecoin',
#  'uniswap',
#  'uniswap',
#  'uniswap',
#  'magic-internet-money',
#  'magic-internet-money',
#  'magic-internet-money',
#  'magic-internet-money',
#  'frax',
#  'frax',
#  'frax',
#  'frax',
#  'compound-ether',
#  'defichain',
#  'defichain',
#  'axie-infinity',
#  'axie-infinity',
#  'the-sandbox',
#  'the-sandbox',
#  'chain-2',
#  'compound-usd-coin',
#  'pancakeswap-token',
#  'huobi-btc',
#  'true-usd',
#  'true-usd',
#  'true-usd',
#  'true-usd',
#  'maker',
#  'decentraland',
#  'decentraland',
#  'huobi-token',
#  'aave',
#  'aave',
#  'aave',
#  'aave',
#  'paxos-standard',
#  'bittorrent',
#  'quant-network',
#  'the-graph',
#  'the-graph',
#  'cdai',
#  'neutrino',
#  'gatechain-token',
#  'bitdao',
#  'fantom',
#  'fantom',
#  'convex-finance',
#  'nexo',
#  'nexo',
#  'stepn',
#  'waves',
#  'compound-usdt',
#  'zilliqa',
#  'frax-share',
#  'frax-share',
#  'frax-share',
#  'frax-share',
#  'pax-gold',
#  'amp-token',
#  'gnosis',
#  'havven',
#  'havven',
#  'havven',
#  'basic-attention-token',
#  'basic-attention-token',
#  'fei-usd',
#  'enjincoin',
#  'chiliz',
#  'xdce-crowd-sale',
#  'gala',
#  'gala',
#  'curve-dao-token',
#  'curve-dao-token',
#  'curve-dao-token',
#  'lido-dao',
#  'lido-dao',
#  'loopring',
#  'tether-gold',
#  'nxm',
#  'tokenize-xchange',
#  'celsius-degree-token',
#  'celsius-degree-token',
#  'celsius-degree-token',
#  'holotoken',
#  'compound-governance-token',
#  'compound-governance-token',
#  'compound-governance-token',
#  'flex-coin',
#  'xido-finance',
#  'xido-finance',
#  'liquity-usd',
#  'liquity-usd',
#  'ecomi',
#  'livepeer',
#  'bancor',
#  'yearn-finance',
#  'yearn-finance',
#  'yearn-finance',
#  '1inch',
#  '1inch',
#  '1inch',
#  'omisego',
#  'serum',
#  'husd',
#  'synapse-2',
#  'synapse-2',
#  'synapse-2',
#  'synapse-2',
#  'everscale',
#  'everscale',
#  'rocket-pool',
#  'convex-crv',
#  '0x',
#  'terra-luna',
#  'safemoon',
#  'olympus',
#  'safemoon-2',
#  'usdd',
#  'usdd',
#  'mimatic',
#  'mimatic',
#  'mimatic',
#  'swissborg',
#  'skale',
#  'titanswap',
#  'ankr',
#  'ankr',
#  'audius',
#  'dogelon-mars',
#  'dogelon-mars',
#  'iotex',
#  'everdome',
#  'escoin-token',
#  'sushi',
#  'sushi',
#  'sushi',
#  'sushi',
#  'gemini-dollar',
#  'tether-eurt',
#  'renbtc',
#  'renbtc',
#  'renbtc',
#  'ethereum-name-service',
#  'apenft',
#  'apenft',
#  'trust-wallet-token',
#  'golem',
#  'render-token',
#  'render-token',
#  'tenset',
#  'tenset',
#  'swipe',
#  'swipe',
#  'illuvium',
#  'woo-network',
#  'woo-network',
#  'woo-network',
#  'woo-network',
#  'rally-2',
#  'immutable-x',
#  'ethos',
#  'alchemix-usd',
#  'mxc',
#  'nucypher',
#  'smooth-love-potion',
#  'dao-maker',
#  'dao-maker',
#  'looksrare',
#  'uma',
#  'dydx',
#  'cratos',
#  'cratos',
#  'radio-caca',
#  'radio-caca',
#  'xsgd',
#  'e-radix',
#  'polymath',
#  'coinex-token',
#  'zipmex-token',
#  'velas',
#  'velas',
#  'mx-token',
#  'flex-usd',
#  'playdapp',
#  'playdapp',
#  'republic-protocol',
#  'telcoin',
#  'telcoin',
#  'kyber-network-crystal',
#  'kyber-network-crystal',
#  'kyber-network-crystal',
#  'kyber-network-crystal',
#  'maple',
#  'multichain',
#  'multichain',
#  'multichain',
#  'multichain',
#  'baby-doge-coin',
#  'baby-doge-coin',
#  'stasis-eurs',
#  'stasis-eurs',
#  'mobox',
#  'tribe-2',
#  'biswap',
#  'ceek',
#  'ceek',
#  'iron-bank-euro',
#  'kirobo',
#  'kirobo',
#  'kirobo',
#  'orbs',
#  'orbs',
#  'orbs',
#  'seth2',
#  'status',
#  'weway',
#  'weway',
#  'insure',
#  'insure',
#  'insure',
#  'chromaway',
#  'chromaway',
#  'spell-token',
#  'spell-token',
#  'merit-circle',
#  'merit-circle',
#  'keep-network',
#  'fx-coin',
#  'asd',
#  'liquity',
#  'hxro',
#  'coti',
#  'injective-protocol',
#  'injective-protocol',
#  'pundi-x-2',
#  'fetch-ai',
#  'fetch-ai',
#  'xyo-network',
#  'vulcan-forged',
#  'vulcan-forged',
#  'cartesi',
#  'cartesi',
#  'cartesi',
#  'funfair',
#  'dent',
#  'ankreth',
#  'dei-token',
#  'dei-token',
#  'dei-token',
#  'balancer',
#  'balancer',
#  'rari-governance-token',
#  'rari-governance-token',
#  'rari-governance-token',
#  'compound-basic-attention-token',
#  'poollotto-finance',
#  'origin-protocol',
#  'ultra',
#  'aavegotchi',
#  'aavegotchi',
#  'nusd',
#  'nusd',
#  'tokemak',
#  'civic',
#  'wazirx',
#  'wazirx',
#  'nest',
#  'gpex',
#  'ocean-protocol',
#  'xsushi',
#  'hermez-network-token',
#  'btse-token',
#  'aurora-near',
#  'railgun',
#  'power-ledger',
#  'perpetual-protocol',
#  'tokamak-network',
#  'creditcoin-2',
#  'digitalbits',
#  'constitutiondao',
#  'lukso-token',
#  'origintrail',
#  'coin98',
#  'coin98',
#  'nerve-finance',
#  'api3',
#  'gensokishis-metaverse',
#  'strike',
#  'reef-finance',
#  'reef-finance',
#  'celer-network',
#  'mdex',
#  'adshares',
#  'adshares',
#  'adshares',
#  'hoo-token',
#  'request-network',
#  'request-network',
#  'metahero',
#  'sifchain',
#  'sifchain',
#  'ampleforth',
#  'ampleforth',
#  'mask-network',
#  'mask-network',
#  'mask-network',
#  'efinity',
#  'sai',
#  'storm',
#  'cvault-finance',
#  'dopex',
#  'sharering',
#  'dawn-protocol',
#  'numeraire',
#  'alpha-finance',
#  'alpha-finance',
#  'reserve-rights-token',
#  'radicle',
#  'quark-chain',
#  'metis-token',
#  'metis-token',
#  'ageur',
#  'ageur',
#  'boba-network',
#  'stratis',
#  'coinmetro',
#  'dola-usd',
#  'dola-usd',
#  'alchemy-pay',
#  'alchemy-pay',
#  'kyber-network',
#  'kyber-network',
#  'metadium',
#  'bezoge-earth',
#  'temple',
#  'storj',
#  'bifrost',
#  'bifrost',
#  'band-protocol',
#  'band-protocol',
#  'floki-inu',
#  'floki-inu',
#  'origin-dollar',
#  'deapcoin',
#  'deapcoin',
#  'platoncoin',
#  'stp-network',
#  'veritaseum',
#  'e-money',
#  'aelf',
#  'interest-bearing-bitcoin',
#  'ellipsis',
#  'singularitynet',
#  'uquid-coin',
#  'shapeshift-fox-token',
#  'shapeshift-fox-token',
#  'orchid-protocol',
#  'unifty',
#  'metal',
#  'propy',
#  'league-of-kingdoms',
#  'everipedia',
#  'everipedia',
#  'everipedia',
#  'boringdao-[old]',
#  'boringdao-[old]',
#  'avinoc',
#  'blox',
#  'dusk-network',
#  'aleph',
#  'aleph',
#  'polkastarter',
#  'polkastarter',
#  'wozx',
#  'tornado-cash',
#  'tornado-cash',
#  'yield-guild-games',
#  'iexec-rlc',
#  'koda-finance',
#  'wrapped-nxm',
#  'yoshi-exchange',
#  'yoshi-exchange',
#  'toucan-protocol-base-carbon-tonne',
#  'truefi',
#  'seth',
#  'superfarm',
#  'superfarm',
#  'superfarm',
#  'orion-protocol',
#  'alpaca-finance',
#  'alpaca-finance',
#  'nkn',
#  'ufo-gaming',
#  'umee',
#  'venus',
#  'kardiachain',
#  'wrapped-centrifuge',
#  'sbtc',
#  'biconomy',
#  'prometeus',
#  'prometeus',
#  'aragon',
#  'nominex',
#  'bitrue-token',
#  'xcad-network',
#  'xcad-network',
#  'xcad-network',
#  'utrust',
#  'rainbow-token-2',
#  'augur',
#  'btc-standard-hashrate-token',
#  'sperax',
#  'mirror-protocol',
#  'mirror-protocol',
#  'pundi-x',
#  'axion',
#  'hunt-token',
#  'unibright',
#  'unibright',
#  'yfii-finance',
#  'feg-token',
#  'bakerytoken',
#  'gyen',
#  'usdk',
#  'cocos-bcx',
#  'cult-dao',
#  'jasmycoin',
#  'cloutcontracts',
#  'cloutcontracts',
#  'rook',
#  'zignaly',
#  'dodo',
#  'dodo',
#  'dodo',
#  'proton',
#  'proton',
#  'musd',
#  'ethlend',
#  'badger-dao',
#  'badger-dao',
#  'covalent',
#  'seedify-fund',
#  'compound-uniswap',
#  'defipulse-index',
#  'defipulse-index',
#  'decentral-games',
#  'decentral-games',
#  'qash',
#  'klima-dao',
#  'kishu-inu',
#  'reflexer-ungovernance-token',
#  'luffy-inu',
#  'luffy-inu',
#  'aergo',
#  'everrise',
#  'everrise',
#  'everrise',
#  'everrise',
#  'keep3rv1',
#  'keep3rv1',
#  'marketpeak',
#  'marketpeak',
#  'neutrino-system-base-token',
#  'silent-notary',
#  'elastos',
#  'alchemix',
#  'my-neighbor-alice',
#  'my-neighbor-alice',
#  'doge-army-token',
#  'starlink',
#  'dopex-rebate-token',
#  'carry',
#  'handshake',
#  'aioz-network',
#  'aioz-network',
#  'butterflydao',
#  'compound-0x',
#  'mainframe',
#  'allianceblock',
#  'safepal',
#  'spookyswap',
#  'spookyswap',
#  'loom-network',
#  'alien-worlds',
#  'noia-network',
#  'noia-network',
#  'rootkit',
#  'melon',
#  'refinable',
#  'qredo',
#  'derivadao',
#  'splinterlands',
#  'anchor-protocol',
#  'auction',
#  'verasity',
#  'beta-finance',
#  'beta-finance',
#  'victoria-vr',
#  'box-token',
#  'dvision-network',
#  'cudos',
#  'automata',
#  'automata',
#  'automata',
#  'token-pocket',
#  'token-pocket',
#  'zenon',
#  'beefy-finance',
#  'beefy-finance',
#  'beefy-finance',
#  'clover-finance',
#  'clover-finance',
#  'sovryn',
#  'adventure-gold',
#  'singularitydao',
#  'singularitydao',
#  'vega-protocol',
#  'rai-finance',
#  'vectorspace',
#  'alpha-quark-token',
#  'gains-farm',
#  'gains-farm',
#  'hi-dollar',
#  'hi-dollar',
#  'dvf',
#  'xmon',
#  'gitcoin',
#  'richquack',
#  'adex',
#  'adex',
#  'adex',
#  'ovr',
#  'ovr',
#  'ovr',
#  'genopets',
#  'quick',
#  'quick',
#  'wilder-world',
#  'qanplatform',
#  'qanplatform',
#  'lcx',
#  'rupiah-token',
#  'swarm-bzz',
#  'rai',
#  'rai',
#  'circuits-of-value',
#  'circuits-of-value',
#  'circuits-of-value',
#  'circuits-of-value',
#  'arpa-chain',
#  'arpa-chain',
#  'woonkly-power',
#  'woonkly-power',
#  'presearch',
#  'eth-2x-flexible-leverage-index',
#  'ribbon-finance',
#  'hopr',
#  'reserve',
#  'bnb48-club-token',
#  'boson-protocol',
#  'refereum',
#  'lto-network',
#  'lto-network',
#  'trustswap',
#  'trustswap',
#  'trustswap',
#  'deus-finance-2',
#  'deus-finance-2',
#  'deus-finance-2',
#  'district0x',
#  'shiba-predator',
#  'marcopolo',
#  'marlin',
#  'popcorn',
#  'magic',
#  'coin-of-the-champions',
#  'coin-of-the-champions',
#  'decentral-games-governance',
#  'decentral-games-governance',
#  'koinos',
#  'saito',
#  'saito',
#  'aurora-dao',
#  'vai',
#  'harvest-finance',
#  'harvest-finance',
#  'x2y2',
#  'bitmart-token',
#  'apollox-2',
#  'nym',
#  'phantasma',
#  'phantasma',
#  'bone-shibaswap',
#  'aeternity',
#  'pha',
#  'alethea-artificial-liquid-intelligence-token',
#  'linear',
#  'linear',
#  'content-value-network',
#  'fodl-finance',
#  'fodl-finance',
#  'polyswarm',
#  'market-making-pro',
#  'mossland',
#  'dxdao',
#  'chronobank',
#  'chronobank',
#  'redfox-labs-2',
#  'redfox-labs-2',
#  'sipher',
#  'whale',
#  'phonon-dao',
#  'idia',
#  'dia-data',
#  'dia-data',
#  'tokocrypto',
#  'guildfi',
#  'morpheus-network',
#  'get-token',
#  'get-token',
#  'somnium-space-cubes',
#  'shibadoge',
#  'mcontent',
#  'mcontent',
#  'tbtc',
#  'ethernity-chain',
#  'fuse-network-token',
#  'fuse-network-token',
#  'fuse-network-token',
#  'lattice-token',
#  'superrare',
#  'yield-app',
#  'yield-app',
#  'velo',
#  'sx-network',
#  'sx-network',
#  'cargox',
#  'cargox',
#  'barnbridge',
#  'spartacus',
#  'grid',
#  'gains-network',
#  'tokenlon',
#  'sentinel-protocol',
#  'hedpay',
#  'bilira',
#  'bilira',
#  'bilira',
#  'hotbit-token',
#  'tomb',
#  'tomb',
#  'ultiledger',
#  'vitadao',
#  'kleros',
#  'civilization',
#  'civilization',
#  'position-token',
#  'nftx',
#  'pinksale',
#  'peculium-2',
#  'metronome',
#  'thorchain-erc20',
#  'ampleforth-governance-token',
#  'bscpad',
#  'unizen',
#  'wirex',
#  'apeswap-finance',
#  'apeswap-finance',
#  'qi-dao',
#  'lockchain',
#  'boringdao',
#  'boringdao',
#  'jade-protocol',
#  'revolution-populi',
#  'mimo-parallel-governance-token',
#  'mimo-parallel-governance-token',
#  'mimo-parallel-governance-token',
#  'tellor',
#  'naga',
#  'meter',
#  'math',
#  'math',
#  'anj',
#  'mixmarvel',
#  'mixmarvel',
#  'cow-protocol',
#  'annex',
#  'bluzelle',
#  'bluzelle',
#  'kryll',
#  'rarible',
#  'dexe',
#  'dexe',
#  'mantra-dao',
#  'mantra-dao',
#  'mantra-dao',
#  'global-coin-research',
#  'global-coin-research',
#  'jpeg-d',
#  'quantstamp',
#  'tranchess',
#  'streamr-xdata',
#  'xdefi',
#  'revv',
#  'revv',
#  'revv',
#  'measurable-data-token',
#  'bigshortbets',
#  'tor',
#  'netvrk',
#  'freeway-token',
#  'freeway-token',
#  'pstake-finance',
#  'oxygen',
#  'blockport',
#  'dextools',
#  'dextools',
#  'vite',
#  'vite',
#  'alpine-f1-team-fan-token',
#  'voxies',
#  'delta-exchange-token',
#  'polkadex',
#  'litentry',
#  'fsn',
#  'fsn',
#  'fsn',
#  'fsn',
#  'yuan-chain-coin',
#  'silo-finance',
#  'paraswap',
#  'paraswap',
#  'paraswap',
#  'hector-dao',
#  'compound-chainlink-token',
#  'catecoin',
#  'santiment-network-token',
#  'givingtoservices-svs',
#  'selfkey',
#  'spool-dao-token',
#  'moviebloc',
#  'talken',
#  'tracer-dao',
#  'vecrv-dao-yvault',
#  'chain-games',
#  'chain-games',
#  'chain-games',
#  'adappter-token',
#  'gemma-extending-tech',
#  'gemma-extending-tech',
#  'crypterium',
#  'parsiq',
#  'parsiq',
#  'xels',
#  'vader-protocol',
#  'derace',
#  'derace',
#  'interest-compounding-eth-index',
#  'banana',
#  'banana',
#  'manifold-finance',
#  'loot',
#  'loot',
#  'tomb-shares',
#  'eden',
#  'stafi',
#  'frontier-token',
#  'frontier-token',
#  'frontier-token',
#  'gamezone',
#  'instadapp',
#  'instadapp',
#  'treeb',
#  'index-cooperative',
#  'index-cooperative',
#  'bella-protocol',
#  'bella-protocol',
#  'pluton',
#  'pluton',
#  'ichi-farm',
#  'xdai-stake',
#  'bepro-network',
#  'alkimi',
#  'bridge',
#  'undead-blocks',
#  'btu-protocol',
#  'btu-protocol',
#  'nectar-token',
#  'the-doge-nft',
#  'the-doge-nft',
#  'the-doge-nft',
#  'solve-care',
#  'terra-virtua-kolect',
#  'lunr-token',
#  'lunr-token',
#  'urus-token',
#  'urus-token',
#  'stake-dao',
#  'stake-dao',
#  'newscrypto-coin',
#  'newscrypto-coin',
#  'bzx-protocol',
#  'bns-token-old',
#  'vvsp',
#  'angle-protocol',
#  'polypad',
#  'polypad',
#  'ariva',
#  'everid',
#  'everid',
#  'cream-2',
#  'cream-2',
#  'qmall',
#  'qmall',
#  'shabu-shabu',
#  'rss3',
#  'bosagora',
#  'paid-network',
#  'paid-network',
#  'stratos',
#  'stackos',
#  'stackos',
#  'stackos',
#  'unicrypt-2',
#  'unicrypt-2',
#  'taboo-token',
#  'tower',
#  'tower',
#  'tower',
#  'ramp',
#  'ramp',
#  'ramp',
#  'era-swap-token',
#  'arianee',
#  'arianee',
#  'seur',
#  'elysia',
#  'pbtc35a',
#  'insurace',
#  'insurace',
#  'insurace',
#  'blockchainspace',
#  'blockchainspace',
#  'peardao',
#  'sideshift-token',
#  'smartofgiving',
#  'smartofgiving',
#  'trustpad',
#  'gamestarter',
#  'gamestarter',
#  'thorswap',
#  'altura',
#  'time-new-bank',
#  'mcdex',
#  'mcdex',
#  'paragonsdao',
#  'lyra-finance',
#  'hackenai',
#  'hackenai',
#  '0chain',
#  '0chain',
#  'zkspace',
#  'veraone',
#  'suku',
#  'banano',
#  'banano',
#  'banano',
#  'opendao',
#  'friends-with-benefits-pro',
#  'rainicorn',
#  'rainicorn',
#  'rainicorn',
#  'panther',
#  'panther',
#  'numbers-protocol',
#  'numbers-protocol',
#  'airswap',
#  'erc20',
#  'erc20',
#  'coin-capsule',
#  'coin-capsule',
#  'switcheo',
#  'switcheo',
#  'occamfi',
#  'occamfi',
#  'foam-protocol',
#  'neos-credits',
#  'cryptex-finance',
#  'rich',
#  'cellframe',
#  'cellframe',
#  'inverse-finance',
#  'velaspad',
#  'velaspad',
#  'sportium',
#  'dfx-finance',
#  'dfx-finance',
#  'unifi-protocol-dao',
#  'unifi-protocol-dao',
#  'wliti',
#  'sora',
#  'label-foundation',
#  'label-foundation',
#  'dforce-token',
#  'bao-finance',
#  'hoge-finance',
#  'hoge-finance',
#  '3x-long-ethereum-token',
#  'gods-unchained',
#  'pnetwork',
#  'pnetwork',
#  'akropolis',
#  'one-ledger',
#  'lunar',
#  'futureswap',
#  'lgcy-network',
#  'byteball',
#  'byteball',
#  'byteball',
#  'breederdao',
#  'flux-token',
#  'gamercoin',
#  'gamercoin',
#  'advertise-coin',
#  'trias-token',
#  'trias-token',
#  'dotmoovs',
#  'dotmoovs',
#  'dotmoovs',
#  'refi',
#  'refi',
#  'opulous',
#  'opulous',
#  'videocoin',
#  'videocoin',
#  'antimatter',
#  'aag-ventures',
#  'polkafoundry',
#  'ethereum-push-notification-service',
#  'ooki',
#  'beethoven-x',
#  'outer-ring',
#  'goldfinch',
#  'metaverse-index',
#  'metaverse-index',
#  'coinweb',
#  'sylo',
#  'neon-exchange',
#  'neon-exchange',
#  'peercoin',
#  'peercoin',
#  'enreachdao',
#  'enreachdao',
#  'rubic',
#  'rubic',
#  'rubic',
#  'premia',
#  'premia',
#  'alchemist',
#  'block-ape-scissors',
#  'mute',
#  'sandclock',
#  'dora-factory',
#  'wasder',
#  'shardus',
#  'shardus',
#  ...]

# %%
# Open a file with access mode 'a'
file_object = open('data/coin_holder.txt', 'a+')
# Append 'hello' at the end of file
file_object.write('Hello')
# Close the file
file_object.close()
